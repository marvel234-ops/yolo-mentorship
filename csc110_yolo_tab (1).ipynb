# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.2 MB/s eta 0:00:00

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f40a025-58d2-4c11-9cf6-a6ad8a68007e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f40a025-58d2-4c11-9cf6-a6ad8a68007e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO("yolov8n.pt")

# Get the actual uploaded filename
uploaded_filename = list(uploaded.keys())[0]

# Set the confidence threshold to 0.5 (50%) to filter detections
results = model(uploaded_filename, conf=0.5)


print("\n========== DETECTION RESULTS ==========")

for result in results:
    boxes = result.boxes

    if len(boxes) == 0:
        print("No objects were detected in the image.")
    else:
        print(f"Number of objects detected: {len(boxes)}\n")
        for i, box in enumerate(boxes):
            class_id = int(box.cls)
            object_name = result.names[class_id]
            confidence = float(box.conf)
            confidence_percent = confidence * 100
            print(f"Object {i+1}: {object_name}")
            print(f"   Confidence: {confidence_percent:.1f}%")
            print()

print("========================================")
print("Lab complete! Great job!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# image 1/1 /content/WhatsApp Image 2026-05-19 at 19.35.45.jpeg: 640x384 1 person, 332.5ms
# Speed: 12.8ms preprocess, 332.5ms inference, 40.3ms postprocess per image at shape (1, 3, 640, 384)
#
# ========== DETECTION RESULTS ==========
# Number of objects detected: 1
#
# Object 1: person
#    Confidence: 90.1%
#
# ...
# Lab complete! Great job!

# %%
from IPython.display import Image as IPImage

# Get the actual uploaded filename
uploaded_filename = list(uploaded.keys())[0]

results[0].save(filename=uploaded_filename)
IPImage(uploaded_filename)
